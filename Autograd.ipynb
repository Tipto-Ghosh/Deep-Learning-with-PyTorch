# %%
import torch

# %%
x = torch.tensor(3.0 , requires_grad = True)

# %%
y = x**2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
# calculating derivative of y 
y.backward()

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
x.grad
# Out:
# tensor(6.)

# %%
x = torch.tensor(3.0 , requires_grad = True)

# %%
y = x ** 2

# %%
z = torch.sin(y)

# %%
x,y,z
# Out:
# (tensor(3., requires_grad=True),
#  tensor(9., grad_fn=<PowBackward0>),
#  tensor(0.4121, grad_fn=<SinBackward0>))

# %%
z.backward() # finding dz/dx

# %%
x.grad
# Out:
# tensor(-5.4668)
